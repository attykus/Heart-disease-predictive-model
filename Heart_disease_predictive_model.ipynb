# %% [markdown]
# <a href="https://colab.research.google.com/github/attykus/Heart-disease-predictive-model/blob/main/Heart_disease_predictive_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7688b41f-1b89-41cf-a000-1c2a05b35cf2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7688b41f-1b89-41cf-a000-1c2a05b35cf2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving heart.csv to heart.csv

# %%
import io

# %%
df=pd.read_csv(io.BytesIO(uploaded['heart.csv']))

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df=df.drop("slope",axis="columns")

# %%
df=df.drop("ca",axis="columns")

# %%
df=df.drop("thal",axis="columns")

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      target
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...

# %%
y=df["target"]

# %%
x=df.drop("target",axis="columns")

# %%
x
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
# [303 rows x 10 columns]

# %%
import os
import tensorflow as tf
from tensorflow.keras import Sequential
import keras.utils
from keras.utils.np_utils import to_categorical


import keras
from keras.models import Sequential
from keras.layers import Dense, Activation

# %%
y=to_categorical(y)

# %%
y.shape
# Out:
# (303, 2)

# %%
model = Sequential([
    Dense(32, input_dim=10),
    Activation('relu'),
    Dense(2),
    Activation('softmax'),
])

# %%
model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])

# %%
model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# 10/10 [==============================] - 1s 1ms/step - loss: 14.7713 - accuracy: 0.5446
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 3.9117 - accuracy: 0.6238
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 3.7160 - accuracy: 0.5875
# Epoch 4/10
# 10/10 [==============================] - 0s 2ms/step - loss: 2.3452 - accuracy: 0.6304
# Epoch 5/10
# 10/10 [==============================] - 0s 2ms/step - loss: 1.7762 - accuracy: 0.6370
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.2149 - accuracy: 0.6733
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9360 - accuracy: 0.6997
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7844 - accuracy: 0.6964
# Epoch 9/10
# 10/10 [==============================] - 0s 2ms/step - loss: 0.7347 - accuracy: 0.6964
# Epoch 10/10
# ...

# %%
x
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
# [303 rows x 10 columns]

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      target
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...

# %%
data=pd.DataFrame({"age":[64],"sex":[1],"cp":[3],"trestbps":[150],"chol":300,"fbs":[1],"restecg":[0],"thalach":[200],"exang":[0],"oldpeak":[2.5]})

# %%
model.predict(data)
# Out:
# array([[0.10341568, 0.89658433]], dtype=float32)
